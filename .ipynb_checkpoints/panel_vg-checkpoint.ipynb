# %%
import pandas as pd
import numpy as np
import hvplot.pandas
import panel as pn
pn.extension('tabulator')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
video_games = pd.read_csv("vgsales.csv")

# %%
vg_cleaned = video_games.dropna(subset = ['Year'])
vg_cleaned.shape
# Out:
# (16327, 11)

# %%
vg_cleaned.head(20)
# Out:
#     Rank                                          Name Platform    Year  \
# 0      1                                    Wii Sports      Wii  2006.0
# 1      2                             Super Mario Bros.      NES  1985.0
# 2      3                                Mario Kart Wii      Wii  2008.0
# 3      4                             Wii Sports Resort      Wii  2009.0
# 4      5                      Pokemon Red/Pokemon Blue       GB  1996.0
# 5      6                                        Tetris       GB  1989.0
# 6      7                         New Super Mario Bros.       DS  2006.0
# 7      8                                      Wii Play      Wii  2006.0
# 8      9                     New Super Mario Bros. Wii      Wii  2009.0
# 9     10                                     Duck Hunt      NES  1984.0
# 10    11                                    Nintendogs       DS  2005.0
# 11    12                                 Mario Kart DS       DS  2005.0
# 12    13                   Pokemon Gold/Pokemon Silver       GB  1999.0
# 13    14                                       Wii Fit      Wii  2007.0
# 14    15                                  Wii Fit Plus      Wii  2009.0
# 15    16                            Kinect Adventures!     X360  2010.0
# 16    17                            Grand Theft Auto V      PS3  2013.0
# 17    18                 Grand Theft Auto: San Andreas      PS2  2004.0
# 18    19                             Super Mario World     SNES  1990.0
# 19    20  Brain Age: Train Your Brain in Minutes a Day       DS  2005.0
#
#            Genre               Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0         Sports                Nintendo     41.49     29.02      3.77
# 1       Platform                Nintendo     29.08      3.58      6.81
# 2         Racing                Nintendo     15.85     12.88      3.79
# 3         Sports                Nintendo     15.75     11.01      3.28
# 4   Role-Playing                Nintendo     11.27      8.89     10.22
# 5         Puzzle                Nintendo     23.20      2.26      4.22
# 6       Platform                Nintendo     11.38      9.23      6.50
# 7           Misc                Nintendo     14.03      9.20      2.93
# 8       Platform                Nintendo     14.59      7.06      4.70
# 9        Shooter                Nintendo     26.93      0.63      0.28
# 10    Simulation                Nintendo      9.07     11.00      1.93
# 11        Racing                Nintendo      9.81      7.57      4.13
# 12  Role-Playing                Nintendo      9.00      6.18      7.20
# 13        Sports                Nintendo      8.94      8.03      3.60
# 14        Sports                Nintendo      9.09      8.59      2.53
# 15          Misc  Microsoft Game Studios     14.97      4.94      0.24
# 16        Action    Take-Two Interactive      7.01      9.27      0.97
# 17        Action    Take-Two Interactive      9.43      0.40      0.41
# 18      Platform                Nintendo     12.78      3.75      3.54
# 19          Misc                Nintendo      4.75      9.26      4.16
#
#     Other_Sales  Global_Sales
# 0          8.46         82.74
# 1          0.77         40.24
# 2          3.31         35.82
# 3          2.96         33.00
# 4          1.00         31.37
# 5          0.58         30.26
# 6          2.90         30.01
# 7          2.85         29.02
# 8          2.26         28.62
# 9          0.47         28.31
# 10         2.75         24.76
# 11         1.92         23.42
# 12         0.71         23.10
# 13         2.15         22.72
# 14         1.79         22.00
# 15         1.67         21.82
# 16         4.14         21.40
# 17        10.57         20.81
# 18         0.55         20.61
# 19         2.05         20.22

# %%
publisher_values = vg_cleaned.groupby(['Year','Publisher'])[["NA_Sales","EU_Sales","JP_Sales","Other_Sales","Global_Sales"]].sum().reset_index()
publisher_values.head(30)
# Out:
#       Year                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0   1980.0                    Activision      2.82      0.18       0.0
# 1   1980.0                         Atari      7.77      0.49       0.0
# 2   1981.0  20th Century Fox Video Games      1.27      0.07       0.0
# 3   1981.0                    Activision      7.95      0.46       0.0
# 4   1981.0                         Atari      7.87      0.47       0.0
# 5   1981.0                        Coleco      2.61      0.15       0.0
# 6   1981.0                      Data Age      0.36      0.02       0.0
# 7   1981.0                        Imagic      4.51      0.27       0.0
# 8   1981.0            Mattel Interactive      2.35      0.13       0.0
# 9   1981.0                  Men-A-Vision      0.72      0.04       0.0
# 10  1981.0                      Mystique      0.76      0.05       0.0
# 11  1981.0                  Parker Bros.      3.14      0.18       0.0
# 12  1981.0                Starpath Corp.      0.30      0.02       0.0
# 13  1981.0                         Taito      0.22      0.01       0.0
# 14  1981.0                   Tigervision      1.07      0.07       0.0
# 15  1981.0                       Unknown      0.27      0.02       0.0
# 16  1982.0  20th Century Fox Video Games      0.55      0.03       0.0
# 17  1982.0                    Activision      1.75      0.11       0.0
# 18  1982.0               Answer Software      0.46      0.03       0.0
# 19  1982.0                         Atari     18.11      1.11       0.0
# 20  1982.0            Avalon Interactive      0.15      0.01       0.0
# 21  1982.0                          Bomb      0.21      0.01       0.0
# 22  1982.0               CBS Electronics      0.29      0.02       0.0
# 23  1982.0                  CPG Products      0.50      0.03       0.0
# 24  1982.0                        Coleco      0.26      0.02       0.0
# 25  1982.0                      Data Age      0.30      0.02       0.0
# 26  1982.0              ITT Family Games      0.32      0.02       0.0
# 27  1982.0            Mattel Interactive      0.37      0.02       0.0
# 28  1982.0                  Parker Bros.      1.05      0.06       0.0
# 29  1982.0                        Quelle      0.81      0.05       0.0
#
#     Other_Sales  Global_Sales
# 0          0.03          3.02
# 1          0.09          8.36
# 2          0.01          1.35
# 3          0.08          8.50
# 4          0.08          8.45
# 5          0.03          2.79
# 6          0.00          0.39
# 7          0.04          4.82
# 8          0.02          2.53
# 9          0.01          0.77
# 10         0.01          0.82
# 11         0.03          3.35
# 12         0.00          0.33
# 13         0.00          0.24
# 14         0.01          1.14
# 15         0.00          0.29
# 16         0.00          0.59
# 17         0.03          1.86
# 18         0.01          0.50
# 19         0.21         19.43
# 20         0.00          0.17
# 21         0.00          0.22
# 22         0.00          0.31
# 23         0.01          0.54
# 24         0.00          0.27
# 25         0.00          0.32
# 26         0.00          0.34
# 27         0.00          0.39
# 28         0.02          1.12
# 29         0.01          0.87

# %%
publisher_unique = list(publisher_values["Publisher"].unique())
publisher_unique
# Out:
# ['Activision',
#  'Atari',
#  '20th Century Fox Video Games',
#  'Coleco',
#  'Data Age',
#  'Imagic',
#  'Mattel Interactive',
#  'Men-A-Vision',
#  'Mystique',
#  'Parker Bros.',
#  'Starpath Corp.',
#  'Taito',
#  'Tigervision',
#  'Unknown',
#  'Answer Software',
#  'Avalon Interactive',
#  'Bomb',
#  'CBS Electronics',
#  'CPG Products',
#  'ITT Family Games',
#  'Quelle',
#  'Sega',
#  'Universal Gamex',
#  'Wizard Video Games',
#  'Nintendo',
#  'Hudson Soft',
#  'Namco Bandai Games',
#  'Capcom',
#  'Mycom',
#  'Konami Digital Entertainment',
#  'Enix Corporation',
#  'SquareSoft',
#  'Maxis',
#  'HAL Laboratory',
#  'Palcom',
#  'Angel Studios',
#  'BPS',
#  'Banpresto',
#  'Culture Brain',
#  'Epoch',
#  'Human Entertainment',
#  'Imagineer',
#  'Kemco',
#  'Square',
#  'Tecmo Koei',
#  'Arena Entertainment',
#  'ChunSoft',
#  'Electronic Arts',
#  'New World Computing',
#  'Ocean',
#  'Takara',
#  'Video System',
#  'Virgin Interactive',
#  'id Software',
#  'Acclaim Entertainment',
#  'Coconuts Japan',
#  'Hect',
#  'Imax',
#  'Interplay',
#  'Laguna',
#  'Misawa',
#  'SNK',
#  'Sammy Corporation',
#  'T&E Soft',
#  'TOHO',
#  'Titus',
#  'Victor Interactive',
#  'ASCII Entertainment',
#  'ArtDink',
#  'Asmik Corp',
#  'Atlus',
#  'Core Design Ltd.',
#  'From Software',
#  'Game Arts',
#  'Hasbro Interactive',
#  'Infogrames',
#  'JVC',
#  'LucasArts',
#  'Media Rings',
#  'Micro Cabin',
#  'Psygnosis',
#  'Red Orb',
#  'Sony Computer Entertainment',
#  'Sunsoft',
#  'Time Warner Interactive',
#  'Vap',
#  'Compile',
#  'Crystal Dynamics',
#  'Data East',
#  'Fuji',
#  'GT Interactive',
#  'Glams',
#  'Imageworks',
#  'Jaleco',
#  'Kokopeli Digital Studios',
#  'MediaQuest',
#  'Microprose',
#  'Mindscape',
#  'NEC',
#  'New',
#  'Nichibutsu',
#  'Pack-In-Video',
#  'Panther Software',
#  'Pow',
#  'Quest',
#  'Riverhillsoft',
#  'SNK Playmore',
#  'Seta Corporation',
#  'Shogakukan',
#  'Sonnet',
#  'THQ',
#  'Technos Japan Corporation',
#  'Telstar',
#  'Tomy Corporation',
#  'U.S. Gold',
#  'Ubisoft',
#  'Vivendi Games',
#  'Yumedia',
#  'ASC Games',
#  'ASK',
#  'Accolade',
#  'Adeline Software',
#  'American Softworks',
#  'Asmik Ace Entertainment',
#  'BMG Interactive Entertainment',
#  'CTO SpA',
#  'Eidos Interactive',
#  'Electronic Arts Victor',
#  'Elf',
#  'Elite',
#  'Empire Interactive',
#  'Fox Interactive',
#  'FunSoft',
#  'Gaga',
#  'Gremlin Interactive Ltd',
#  'Gust',
#  'Hearty Robin',
#  'KSS',
#  'Kadokawa Shoten',
#  'Media Works',
#  'Microsoft Game Studios',
#  'Midway Games',
#  'NCS',
#  'NEC Interchannel',
#  'Natsume',
#  'Nippon Telenet',
#  'Pioneer LDC',
#  'SPS',
#  'SSI',
#  'Societa',
#  'Vic Tokai',
#  '989 Studios',
#  'Agetec',
#  'Aques',
#  'Codemasters',
#  'ESP',
#  'Hudson Entertainment',
#  'Imadio',
#  'Interplay Productions',
#  'Midas Interactive Entertainment',
#  'On Demand',
#  'Origin Systems',
#  'Playmates',
#  'Starfish',
#  'Take-Two Interactive',
#  'UEP Systems',
#  'Warp',
#  'Xing Entertainment',
#  '3DO',
#  'Axela',
#  'Crave Entertainment',
#  'Culture Publishers',
#  'D3Publisher',
#  'DreamWorks Interactive',
#  'Evolution Games',
#  'Fortyfive',
#  'Gainax Network Systems',
#  'GameTek',
#  'General Entertainment',
#  'Irem Software Engineering',
#  'KID',
#  'Locus',
#  'MTO',
#  'Magical Company',
#  'Mitsui',
#  'NewKidCo',
#  'Nippon Ichi Software',
#  'Quintet',
#  'Saurus',
#  'Success',
#  'Swing! Entertainment',
#  'Syscom',
#  'TYO',
#  'TechnoSoft',
#  '989 Sports',
#  'Aqua Plus',
#  'Aruze Corp',
#  'Athena',
#  'Disney Interactive Studios',
#  'EON Digital Entertainment',
#  'Genki',
#  'Jorudan',
#  'LEGO Media',
#  'Pack In Soft',
#  'PopTop Software',
#  'Red Storm Entertainment',
#  'SouthPeak Games',
#  'Square EA',
#  'Telegames',
#  'Westwood Studios',
#  'BAM! Entertainment',
#  'Havas Interactive',
#  'Media Factory',
#  'Pony Canyon',
#  'Sunrise Interactive',
#  'TDK Core',
#  'The Learning Company',
#  'Vatical Entertainment',
#  'Activision Value',
#  'Altron',
#  'Berkeley',
#  'Blue Byte',
#  'Conspiracy Entertainment',
#  'Destination Software, Inc',
#  'DreamCatcher Interactive',
#  'Encore',
#  'Enterbrain',
#  'Gathering of Developers',
#  'Magix',
#  'Majesco Entertainment',
#  'Max Five',
#  'Metro 3D',
#  'Rage Software',
#  'Rebellion',
#  'Sony Computer Entertainment Europe',
#  'Sony Music Entertainment',
#  'Spike',
#  'Strategy First',
#  'TDK Mediactive',
#  'TalonSoft',
#  'Universal Interactive',
#  'Wanadoo',
#  '505 Games',
#  'Arika',
#  'Bethesda Softworks',
#  'Big Ben Interactive',
#  'Black Label Games',
#  'Datam Polystar',
#  'DigiCube',
#  'Gotham Games',
#  'Hamster Corporation',
#  'Idea Factory',
#  'Ignition Entertainment',
#  'Jester Interactive',
#  'JoWood Productions',
#  'King Records',
#  'LSP Games',
#  'Liquid Games',
#  'Marvelous Interactive',
#  'Media Entertainment',
#  'Microids',
#  'NDA Productions',
#  'Nippon Amuse',
#  'Pacific Century Cyber Works',
#  'Phantagram',
#  'Play It',
#  'Playmore',
#  'Princess Soft',
#  'SCi',
#  'Simon & Schuster Interactive',
#  'XS Games',
#  'Xicat Interactive',
#  'Zoo Digital Publishing',
#  'Aspyr',
#  'CCP',
#  'Game Factory',
#  'Ghostlight',
#  'Knowledge Adventure',
#  'Kool Kizz',
#  'Mud Duck Productions',
#  'Sony Online Entertainment',
#  'Square Enix',
#  'Warner Bros. Interactive Entertainment',
#  'Agatsuma Entertainment',
#  'Ascaron Entertainment GmbH',
#  'Deep Silver',
#  'Evolved Games',
#  'Global Star',
#  'Hip Interactive',
#  'Illusion Softworks',
#  'Indie Games',
#  'MC2 Entertainment',
#  'Mad Catz',
#  'Mastiff',
#  'O3 Entertainment',
#  'Sting',
#  'Summitsoft',
#  'Sunflowers',
#  'responDESIGN',
#  'Black Bean Games',
#  'CDV Software Entertainment',
#  'DSI Games',
#  'DTP Entertainment',
#  'Essential Games',
#  'Flashpoint Games',
#  'Graphsim Entertainment',
#  'Groove Games',
#  'Jack of All Games',
#  'NCSoft',
#  'NovaLogic',
#  'Oxygen Interactive',
#  'Playlogic Game Factory',
#  'RedOctane',
#  'Rising Star Games',
#  'Valcon Games',
#  'ValuSoft',
#  'Xplosiv',
#  "Yuke's",
#  '10TACLE Studios',
#  'Acquire',
#  'Alchemist',
#  'Aria',
#  'Broccoli',
#  'Daito',
#  'Edia',
#  'Focus Home Interactive',
#  'Funsta',
#  'GN Software',
#  'Global A Entertainment',
#  'IE Institute',
#  'Interchannel',
#  'Kando Games',
#  'Mastertronic',
#  'Michaelsoft',
#  'Mumbo Jumbo',
#  'Myelin Media',
#  'Ongakukan',
#  'PopCap Games',
#  'Rocket Company',
#  'Sweets',
#  'System 3 Arcade Software',
#  'Takara Tomy',
#  'Yamasa Entertainment',
#  'Yeti',
#  'Zenrin',
#  'AQ Interactive',
#  'Avanquest',
#  'Benesse',
#  'Blast! Entertainment Ltd',
#  'Brash Entertainment',
#  'CokeM Interactive',
#  'CyberFront',
#  'DHM Interactive',
#  'Data Design Interactive',
#  'Destineer',
#  'Detn8 Games',
#  'Ertain',
#  'Falcom Corporation',
#  'Flight-Plan',
#  'Gakken',
#  'Game Life',
#  'Gameloft',
#  'Grand Prix Games',
#  'Hackberry',
#  'Interchannel-Holon',
#  'Kalypso Media',
#  'Kids Station',
#  'Lexicon Entertainment',
#  'Lighthouse Interactive',
#  'Mercury Games',
#  'Monte Christo Multimedia',
#  'Neko Entertainment',
#  'Nobilis',
#  'Nordcurrent',
#  'PQube',
#  'Paon',
#  'Paradox Interactive',
#  'Phenomedia',
#  'Phoenix Games',
#  'Popcorn Arcade',
#  'Prototype',
#  'RTL',
#  'Russel',
#  'Scholastic Inc.',
#  'Tommo',
#  'Touchstone',
#  'UFO Interactive',
#  'Warashi',
#  'White Park Bay Software',
#  'Zushi Games',
#  '2D Boy',
#  '5pb',
#  'ASCII Media Works',
#  'Aksys Games',
#  'Arc System Works',
#  'Big Fish Games',
#  'Cave',
#  'City Interactive',
#  'Codemasters Online',
#  'Commseed',
#  'Compile Heart',
#  'Creative Core',
#  'Crimson Cow',
#  'Dorart',
#  'GOA',
#  'GSP',
#  'Gamebridge',
#  'Gamecock',
#  'Graffiti',
#  'GungHo',
#  'HMH Interactive',
#  'Ivolgamus',
#  'Koch Media',
#  'Legacy Interactive',
#  'MTV Games',
#  'Mamba Games',
#  'Milestone',
#  'Minato Station',
#  'Mirai Shounen',
#  'Moss',
#  'Navarre Corp',
#  'Naxat Soft',
#  'Nordic Games',
#  'Pinnacle',
#  'Rondomedia',
#  'System Soft',
#  'The Adventure Company',
#  'Tivola',
#  'Tryfirst',
#  'Vir2L Studios',
#  'Zoo Games',
#  'fonfun',
#  '1C Company',
#  '49Games',
#  'Ackkstudios',
#  'Alawar Entertainment',
#  'Alvion',
#  'Astragon',
#  'Daedalic',
#  'Ecole',
#  'Enjoy Gaming ltd.',
#  'G.Rev',
#  'Genterprise',
#  'Level 5',
#  'Mentor Interactive',
#  'Merscom LLC',
#  'Number None',
#  'O-Games',
#  'P2 Games',
#  'PM Studios',
#  'Performance Designed Products',
#  'Phantom EFX',
#  'PlayV',
#  'Reef Entertainment',
#  'Revolution (Japan)',
#  'Slitherine Software',
#  'Storm City Games',
#  'TGL',
#  'Ubisoft Annecy',
#  'Valve Software',
#  'bitComposer Games',
#  '7G//AMES',
#  'Abylight',
#  'Aerosoft',
#  'Alternative Software',
#  'Asgard',
#  'Asylum Entertainment',
#  'Comfort',
#  'Devolver Digital',
#  'Foreign Media Games',
#  'FuRyu',
#  'Funcom',
#  'GameMill Entertainment',
#  'Griffin International',
#  'Home Entertainment Suppliers',
#  'Just Flight',
#  'Kamui',
#  'Karin Entertainment',
#  'Little Orbit',
#  'NetRevo',
#  'Nexon',
#  'Piacci',
#  'RED Entertainment',
#  'Team17 Software',
#  'Tradewest',
#  'Virtual Play Games',
#  'Excalibur Publishing',
#  'Funbox Media',
#  'Her Interactive',
#  'Iceberg Interactive',
#  'Masque Publishing',
#  'Plenty',
#  'Quinrose',
#  'Takuyo',
#  'Telltale Games',
#  'Tetris Online',
#  'TopWare Interactive',
#  'Tripwire Interactive',
#  'Valve',
#  'Visco',
#  'Wargaming.net',
#  'iWin',
#  'Ascaron Entertainment',
#  'Avanquest Software',
#  'BushiRoad',
#  'Cloud Imperium Games Corporation',
#  'Daedalic Entertainment',
#  'EA Games',
#  'Easy Interactive',
#  'Fields',
#  'Focus Multimedia',
#  'Giza10',
#  'Image Epoch',
#  'Interworks Unlimited, Inc.',
#  'Kadokawa Games',
#  'Licensed 4U',
#  'Marvelous Entertainment',
#  'Maximum Family Games',
#  'Nihon Falcom Corporation',
#  'Nippon Columbia',
#  'SCS Software',
#  'Trion Worlds',
#  'Views',
#  'Xseed Games',
#  'Bohemia Interactive',
#  'Boost On',
#  'Headup Games',
#  'Kaga Create',
#  'Office Create',
#  'Otomate',
#  'Paon Corporation',
#  'Screenlife',
#  'Seventh Chord',
#  'System 3',
#  'Activision Blizzard',
#  'Experience Inc.',
#  'Giga',
#  'Happinet',
#  'Idea Factory International',
#  'Milestone S.r.l.',
#  'Nitroplus',
#  'Sony Computer Entertainment America',
#  'Tru Blu Entertainment',
#  'Type-Moon',
#  'imageepoch Inc.',
#  'Bigben Interactive',
#  'Cygames',
#  'Extreme Entertainment Group',
#  'FuRyu Corporation',
#  'Harmonix Music Systems',
#  'HuneX',
#  'Intergrow',
#  'Marvel Entertainment',
#  'Marvelous Games',
#  'Mojang',
#  'Rain Games',
#  'Rebellion Developments',
#  'Revolution Software',
#  'Slightly Mad Studios',
#  'WayForward Technologies',
#  'Yacht Club Games',
#  'dramatic create',
#  'inXile Entertainment',
#  'mixi, Inc',
#  'Dusenberry Martin Racing',
#  'Epic Games',
#  'Hello Games',
#  'Insomniac Games',
#  'Inti Creates',
#  'Introversion Software',
#  'MLB.com',
#  'Milestone S.r.l',
#  'Paradox Development',
#  'Sold Out',
#  'Stainless Games',
#  'UIG Entertainment']

# %%
publisher_int = publisher_values.interactive()

# %%
year_slider = pn.widgets.IntSlider(name = 'Year slider',start = 1980,end = 2020,step = 5,value = 2000)
year_slider
# Out:
# IntSlider(end=2020, name='Year slider', start=1980, step=5, value=2000)

# %%
publisher_select = pn.widgets.Select(name = "Publisher Names",options = publisher_unique)
publisher_select
# Out:
# Select(name='Publisher Names', options=['Activision', ...], value='Activision')

# %%
co2_pipeline = (
    publisher_int[
        publisher_int["Publisher"] == publisher_select
    ]
    .sort_values(by='Year')  
    .reset_index(drop=True)
)
co2_pipeline
# Out:
# <div id='5829f2ba-5edb-4e33-ac69-b2229ba2712f'>
#   <div id="a8deb846-312d-4fac-bede-1b63e5218d02" data-root-id="5829f2ba-5edb-4e33-ac69-b2229ba2712f" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"e7e3a909-f531-424e-8b86-5287e3b0dd5e":{"version":"3.2.2","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"5829f2ba-5edb-4e33-ac69-b2229ba2712f","attributes":{"name":"Row01020","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"1bb34c0f-2ebe-4ec3-8e40-f622829f958f","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"8be14e9a-0e64-49df-958e-97af605714a3","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"956c0823-aee9-4788-be2c-c130be11f61a","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"73193e15-448a-4ed1-86e4-5d92114d8bc1","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"d528841a-5c4b-4503-b33e-96e6f9d572df","attributes":{"name":"Column01017","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"1bb34c0f-2ebe-4ec3-8e40-f622829f958f"},{"id":"8be14e9a-0e64-49df-958e-97af605714a3"},{"id":"956c0823-aee9-4788-be2c-c130be11f61a"},{"id":"73193e15-448a-4ed1-86e4-5d92114d8bc1"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"a2252a47-d580-49fe-a916-5e6d208efb8d","attributes":{"name":"Column00987","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"1bb34c0f-2ebe-4ec3-8e40-f622829f958f"},{"id":"8be14e9a-0e64-49df-958e-97af605714a3"},{"id":"956c0823-aee9-4788-be2c-c130be11f61a"},{"id":"73193e15-448a-4ed1-86e4-5d92114d8bc1"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.widgets.CustomSelect","id":"eebcf7b2-7326-4878-b1e4-38af64d35e06","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"1bb34c0f-2ebe-4ec3-8e40-f622829f958f"},{"type":"object","name":"ImportedStyleSheet","id":"627f711a-08b1-444a-be44-bdde2adeb199","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/select.css"}},{"id":"956c0823-aee9-4788-be2c-c130be11f61a"},{"id":"73193e15-448a-4ed1-86e4-5d92114d8bc1"}],"width":300,"min_width":300,"margin":[5,10],"align":"start","title":"Publisher Names","options":["Activision","Atari","20th Century Fox Video Games","Coleco","Data Age","Imagic","Mattel Interactive","Men-A-Vision","Mystique","Parker Bros.","Starpath Corp.","Taito","Tigervision","Unknown","Answer Software","Avalon Interactive","Bomb","CBS Electronics","CPG Products","ITT Family Games","Quelle","Sega","Universal Gamex","Wizard Video Games","Nintendo","Hudson Soft","Namco Bandai Games","Capcom","Mycom","Konami Digital Entertainment","Enix Corporation","SquareSoft","Maxis","HAL Laboratory","Palcom","Angel Studios","BPS","Banpresto","Culture Brain","Epoch","Human Entertainment","Imagineer","Kemco","Square","Tecmo Koei","Arena Entertainment","ChunSoft","Electronic Arts","New World Computing","Ocean","Takara","Video System","Virgin Interactive","id Software","Acclaim Entertainment","Coconuts Japan","Hect","Imax","Interplay","Laguna","Misawa","SNK","Sammy Corporation","T&E Soft","TOHO","Titus","Victor Interactive","ASCII Entertainment","ArtDink","Asmik Corp","Atlus","Core Design Ltd.","From Software","Game Arts","Hasbro ...

# %%
Sales = ['NA_Sales','EU_Sales','JP_Sales','Other_Sales','Global_Sales']
publisher_plot = co2_pipeline.hvplot(x = 'Year',y = Sales,by = Sales,line_width = 2,title = "Publisher Sales")
publisher_plot
# Out:
# C:\Users\shubh\Dropbox\My PC (LAPTOP-U0VR69II)\Desktop\Python Projects\Data Analyst\data_analysis\Lib\site-packages\holoviews\core\data\pandas.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return dataset.data.dtypes[idx].type
# C:\Users\shubh\Dropbox\My PC (LAPTOP-U0VR69II)\Desktop\Python Projects\Data Analyst\data_analysis\Lib\site-packages\holoviews\core\data\pandas.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return dataset.data.dtypes[idx].type
# <div id='7ef09d60-5416-4b92-98d6-7598a1ae04e7'>
#   <div id="fe71d514-9418-4a6d-8653-5663ea9cf644" data-root-id="7ef09d60-5416-4b92-98d6-7598a1ae04e7" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"a9c88bf8-4b68-4cc3-9161-8904efe27aae":{"version":"3.2.2","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"7ef09d60-5416-4b92-98d6-7598a1ae04e7","attributes":{"name":"Row01286","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"b7322862-979c-4c00-82dd-dcfef3901059","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"90586eb7-5934-4a1d-aebe-094a7ed5e018","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"7aa5c071-cccd-4eec-aaf5-68d12c536c17","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"351179f7-a60e-4622-8503-826030c4293f","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"f87be77e-c2cf-4e52-ad06-80d4ba8f4131","attributes":{"name":"Column01283","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"b7322862-979c-4c00-82dd-dcfef3901059"},{"id":"90586eb7-5934-4a1d-aebe-094a7ed5e018"},{"id":"7aa5c071-cccd-4eec-aaf5-68d12c536c17"},{"id":"351179f7-a60e-4622-8503-826030c4293f"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"a1c2762c-b82d-492b-8db2-a17bf5b299a9","attributes":{"name":"Column01266","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"b7322862-979c-4c00-82dd-dcfef3901059"},{"id":"90586eb7-5934-4a1d-aebe-094a7ed5e018"},{"id":"7aa5c071-cccd-4eec-aaf5-68d12c536c17"},{"id":"351179f7-a60e-4622-8503-826030c4293f"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.widgets.CustomSelect","id":"49479c5d-3586-42ca-ab63-221101f788e2","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"b7322862-979c-4c00-82dd-dcfef3901059"},{"type":"object","name":"ImportedStyleSheet","id":"1e7c0c88-56b4-47b5-a0db-f9acdef3ea7c","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/select.css"}},{"id":"7aa5c071-cccd-4eec-aaf5-68d12c536c17"},{"id":"351179f7-a60e-4622-8503-826030c4293f"}],"width":300,"min_width":300,"margin":[5,10],"align":"start","title":"Publisher Names","options":["Activision","Atari","20th Century Fox Video Games","Coleco","Data Age","Imagic","Mattel Interactive","Men-A-Vision","Mystique","Parker Bros.","Starpath Corp.","Taito","Tigervision","Unknown","Answer Software","Avalon Interactive","Bomb","CBS Electronics","CPG Products","ITT Family Games","Quelle","Sega","Universal Gamex","Wizard Video Games","Nintendo","Hudson Soft","Namco Bandai Games","Capcom","Mycom","Konami Digital Entertainment","Enix Corporation","SquareSoft","Maxis","HAL Laboratory","Palcom","Angel Studios","BPS","Banpresto","Culture Brain","Epoch","Human Entertainment","Imagineer","Kemco","Square","Tecmo Koei","Arena Entertainment","ChunSoft","Electronic Arts","New World Computing","Ocean","Takara","Video System","Virgin Interactive","id Software","Acclaim Entertainment","Coconuts Japan","Hect","Imax","Interplay","Laguna","Misawa","SNK","Sammy Corporation","T&E Soft","TOHO","Titus","Victor Interactive","ASCII Entertainment","ArtDink","Asmik Corp","Atlus","Core Design Ltd.","From Software","Game Arts","Hasbro ...

# %%
genre_val = vg_cleaned.groupby(["Year","Genre"])[["NA_Sales","EU_Sales","JP_Sales","Other_Sales","Global_Sales"]].sum().reset_index()

# %%
genre_int = genre_val.interactive()

# %%
genre_select = pn.widgets.Select(name = "Genre's",options = list(genre_val["Genre"].unique()))

# %%
genre_select
# Out:
# Select(name="Genre's", options=['Action', 'Fighting', ...], value='Action')

# %%
genre_pipline = (
    genre_int[(genre_int.Year <= year_slider) & (genre_int["Genre"] == genre_select)] 
).sort_values("Year").reset_index()

# %%
genre_plot = genre_pipline.hvplot(x = 'Year',y = Sales,by = Sales,line_width = 2,title = "Genre Sales")
genre_plot
# Out:
# C:\Users\shubh\Dropbox\My PC (LAPTOP-U0VR69II)\Desktop\Python Projects\Data Analyst\data_analysis\Lib\site-packages\holoviews\core\data\pandas.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return dataset.data.dtypes[idx].type
# C:\Users\shubh\Dropbox\My PC (LAPTOP-U0VR69II)\Desktop\Python Projects\Data Analyst\data_analysis\Lib\site-packages\holoviews\core\data\pandas.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return dataset.data.dtypes[idx].type
# <div id='54f57a8d-acfa-4410-9720-41cdadb7f431'>
#   <div id="ee030b72-98d8-4c95-92bd-2b87a1b56cf1" data-root-id="54f57a8d-acfa-4410-9720-41cdadb7f431" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"476a29e6-5f40-4c45-8823-53ac0713a863":{"version":"3.2.2","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"54f57a8d-acfa-4410-9720-41cdadb7f431","attributes":{"name":"Row01910","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"4fc8d8cd-6efd-4757-b5d5-586d7350c12b","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"7b5a4bca-4789-4445-9693-527fdc69ab38","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"208f3e18-4a2e-4d1c-a588-51cc1ed72b04","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"716d24f7-07ef-4939-b466-a3b69794ffff","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"ee82ccbf-d946-4dd6-b076-7a7e466cd2f8","attributes":{"name":"Column01907","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"4fc8d8cd-6efd-4757-b5d5-586d7350c12b"},{"id":"7b5a4bca-4789-4445-9693-527fdc69ab38"},{"id":"208f3e18-4a2e-4d1c-a588-51cc1ed72b04"},{"id":"716d24f7-07ef-4939-b466-a3b69794ffff"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"d2487aee-31ba-4780-8340-734401fa1285","attributes":{"name":"Column01890","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"4fc8d8cd-6efd-4757-b5d5-586d7350c12b"},{"id":"7b5a4bca-4789-4445-9693-527fdc69ab38"},{"id":"208f3e18-4a2e-4d1c-a588-51cc1ed72b04"},{"id":"716d24f7-07ef-4939-b466-a3b69794ffff"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"4fa4314a-73a3-48dc-9834-db5b986b24aa","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"4fc8d8cd-6efd-4757-b5d5-586d7350c12b"},{"id":"208f3e18-4a2e-4d1c-a588-51cc1ed72b04"},{"id":"716d24f7-07ef-4939-b466-a3b69794ffff"}],"margin":[5,10],"align":"start","title":"Year slider","start":1980,"end":2020,"value":2000,"step":5}},{"type":"object","name":"panel.models.widgets.CustomSelect","id":"f7d373da-cc96-4755-a006-dba3879248bd","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"4fc8d8cd-6efd-4757-b5d5-586d7350c12b"},{"type":"object","name":"ImportedStyleSheet","id":"4f4ac3c8-de13-4670-bac2-9be548474715","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/select.css"}},{"id":"208f3e18-4a2e-4d1c-a588-51cc1ed72b04"},{"id":"716d24f7-07ef-4939-b466-a3b69794ffff"}],"width":300,"min_width":300,"margin":[5,10],"align":"start","title":"Genre's","options":["Action","Fighting","Misc","Shooter","Sports","Platform","Puzzle","Racing","Simulation","Adventure","Role-Playing","Strategy"],"value":"Action"}}]}},{"type":"object","name":"Figure","id":"ed4d7e22-f0e5-4bb6-af80-8a4d7497f888","attributes":{"width":700,"height":300,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"Range1d","id":"062dc5f2-613d-4683-a9f8-98e51b4a5940","attributes":{"tags":[[["Year","Year",null]],[]],"start":1980.0,"end":2000.0,"reset_start":1980.0,"reset_end ...

# %%
publisher_genre = vg_cleaned.groupby(['Publisher','Genre'])[["NA_Sales","EU_Sales","JP_Sales","Other_Sales","Global_Sales"]].sum().reset_index()
publisher_genre_int = publisher_genre.interactive()

# %%
publisher_genre_select = pn.widgets.Select(name = "Publisher Names",options = list(publisher_genre["Publisher"].unique()))

# %%
publisher_genre_select
# Out:
# Select(name='Publisher Names', options=['10TACLE Studios', ...], value='10TACLE Studios')

# %%
publisher_genre_pipeline = (
    publisher_genre_int[publisher_int["Publisher"] == publisher_select].sort_values('Publisher').reset_index()
)

# %%
publisher_genre_pipeline
# Out:
# <div id='4fe6c2d4-229b-4d11-aa18-1fc9c914e9df'>
#   <div id="c42cebcc-7455-40cd-ae42-4ff938d77c82" data-root-id="4fe6c2d4-229b-4d11-aa18-1fc9c914e9df" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"0edae45a-0281-44b0-9cb1-15395fe33846":{"version":"3.2.2","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"4fe6c2d4-229b-4d11-aa18-1fc9c914e9df","attributes":{"name":"Row02234","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"2f5cf726-cd82-430a-9f02-dce18ced9978","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"ae70b944-1826-4836-810e-f046fc96dff5","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"f4894dfb-665b-4c2a-9385-4b59dcfb57ce","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"5dac954b-a5a7-4ba5-9967-147fd1e1c21e","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"cc637c54-7a99-4a1c-9046-d1a68468c1a1","attributes":{"name":"Column02231","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"2f5cf726-cd82-430a-9f02-dce18ced9978"},{"id":"ae70b944-1826-4836-810e-f046fc96dff5"},{"id":"f4894dfb-665b-4c2a-9385-4b59dcfb57ce"},{"id":"5dac954b-a5a7-4ba5-9967-147fd1e1c21e"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"0d3fd3fd-e61f-4f10-b6f1-030b594e7128","attributes":{"name":"Column02201","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"2f5cf726-cd82-430a-9f02-dce18ced9978"},{"id":"ae70b944-1826-4836-810e-f046fc96dff5"},{"id":"f4894dfb-665b-4c2a-9385-4b59dcfb57ce"},{"id":"5dac954b-a5a7-4ba5-9967-147fd1e1c21e"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.widgets.CustomSelect","id":"46289daa-f39b-40c9-a8b3-03c74799f0bb","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"2f5cf726-cd82-430a-9f02-dce18ced9978"},{"type":"object","name":"ImportedStyleSheet","id":"6de504ae-148b-4839-91dd-3a72b80e001c","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/select.css"}},{"id":"f4894dfb-665b-4c2a-9385-4b59dcfb57ce"},{"id":"5dac954b-a5a7-4ba5-9967-147fd1e1c21e"}],"width":300,"min_width":300,"margin":[5,10],"align":"start","title":"Publisher Names","options":["Activision","Atari","20th Century Fox Video Games","Coleco","Data Age","Imagic","Mattel Interactive","Men-A-Vision","Mystique","Parker Bros.","Starpath Corp.","Taito","Tigervision","Unknown","Answer Software","Avalon Interactive","Bomb","CBS Electronics","CPG Products","ITT Family Games","Quelle","Sega","Universal Gamex","Wizard Video Games","Nintendo","Hudson Soft","Namco Bandai Games","Capcom","Mycom","Konami Digital Entertainment","Enix Corporation","SquareSoft","Maxis","HAL Laboratory","Palcom","Angel Studios","BPS","Banpresto","Culture Brain","Epoch","Human Entertainment","Imagineer","Kemco","Square","Tecmo Koei","Arena Entertainment","ChunSoft","Electronic Arts","New World Computing","Ocean","Takara","Video System","Virgin Interactive","id Software","Acclaim Entertainment","Coconuts Japan","Hect","Imax","Interplay","Laguna","Misawa","SNK","Sammy Corporation","T&E Soft","TOHO","Titus","Victor Interactive","ASCII Entertainment","ArtDink","Asmik Corp","Atlus","Core Design Ltd.","From Software","Game Arts","Hasbro ...

# %%
publisher_genre_plot = publisher_genre_pipeline.hvplot(kind = 'bar',x='Genre',y = 'Global_Sales',title = 'Genre-based sales trends over time')
publisher_genre_plot
# Out:
# C:\Users\shubh\Dropbox\My PC (LAPTOP-U0VR69II)\Desktop\Python Projects\Data Analyst\data_analysis\Lib\site-packages\holoviews\core\util.py:1175: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   return pd.unique(values)
# C:\Users\shubh\Dropbox\My PC (LAPTOP-U0VR69II)\Desktop\Python Projects\Data Analyst\data_analysis\Lib\site-packages\holoviews\core\util.py:1175: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   return pd.unique(values)
# C:\Users\shubh\Dropbox\My PC (LAPTOP-U0VR69II)\Desktop\Python Projects\Data Analyst\data_analysis\Lib\site-packages\holoviews\core\data\pandas.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return dataset.data.dtypes[idx].type
# <div id='7c77ff52-5b46-4e74-bea2-e2c375869ce9'>
#   <div id="f1f963b1-7a15-4399-9076-aa5a6c1a4508" data-root-id="7c77ff52-5b46-4e74-bea2-e2c375869ce9" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"160fbcf9-4f39-43ed-8339-3b26a02f793d":{"version":"3.2.2","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"7c77ff52-5b46-4e74-bea2-e2c375869ce9","attributes":{"name":"Row09989","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"5becf99b-e11c-43a6-825a-91433ebae83b","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"9e0940c3-5103-4e66-918d-e1590e9be6d9","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"b0a1100d-5711-47f9-ab43-650cbb256889","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"8e064f6f-6ec0-49ce-aece-862e4acf894f","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"830b3516-acf6-4a36-a77e-4f86b5be3da8","attributes":{"name":"Column09986","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"5becf99b-e11c-43a6-825a-91433ebae83b"},{"id":"9e0940c3-5103-4e66-918d-e1590e9be6d9"},{"id":"b0a1100d-5711-47f9-ab43-650cbb256889"},{"id":"8e064f6f-6ec0-49ce-aece-862e4acf894f"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"3f1b49cc-6d00-4c69-ab75-b7903fcf0f55","attributes":{"name":"Column09969","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"5becf99b-e11c-43a6-825a-91433ebae83b"},{"id":"9e0940c3-5103-4e66-918d-e1590e9be6d9"},{"id":"b0a1100d-5711-47f9-ab43-650cbb256889"},{"id":"8e064f6f-6ec0-49ce-aece-862e4acf894f"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.widgets.CustomSelect","id":"57267c07-7af0-41ef-b9d2-cc300d3d43c1","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"5becf99b-e11c-43a6-825a-91433ebae83b"},{"type":"object","name":"ImportedStyleSheet","id":"eabcfa7e-5345-4a7a-bb21-56a78f58e7c9","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/select.css"}},{"id":"b0a1100d-5711-47f9-ab43-650cbb256889"},{"type":"object","name":"ImportedStyleSheet","id":"97fc2189-3069-40ea-973b-8841c85d3b92","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/fast.css"}}],"width":300,"min_width":300,"margin":[5,10],"align":"start","title":"Publisher Names","options":["Activision","Atari","20th Century Fox Video Games","Coleco","Data Age","Imagic","Mattel Interactive","Men-A-Vision","Mystique","Parker Bros.","Starpath Corp.","Taito","Tigervision","Unknown","Answer Software","Avalon Interactive","Bomb","CBS Electronics","CPG Products","ITT Family Games","Quelle","Sega","Universal Gamex","Wizard Video Games","Nintendo","Hudson Soft","Namco Bandai Games","Capcom","Mycom","Konami Digital Entertainment","Enix Corporation","SquareSoft","Maxis","HAL Laboratory","Palcom","Angel Studios","BPS","Banpresto","Culture Brain","Epoch","Human Entertainment","Imagineer","Kemco","Square","Tecmo Koei","Arena Entertainment","ChunSoft","Electronic Arts","New World Computing","Ocean","Takara","Video System","Virgin Interactive","id Software","Acclaim Entertainment","Coconuts Japan","Hect","Imax","Interplay","Laguna","Misawa","SNK","Sammy Corporation","T&E Soft","TOHO","Titu ...

# %%
vg_cleaned.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
sales_data = vg_cleaned[["Year","NA_Sales","EU_Sales","JP_Sales","Other_Sales","Global_Sales"]].sort_values(by = "Year").reset_index()
sales_data = sales_data.groupby("Year")[Sales].sum().reset_index()

# %%
sales_data_int = sales_data.interactive()

# %%
sales_data_plot = sales_data_int.hvplot(x = "Year",y = Sales,line_width = 2,title = "Sales performance over time")

# %%
sales_data_plot
# Out:
# C:\Users\shubh\Dropbox\My PC (LAPTOP-U0VR69II)\Desktop\Python Projects\Data Analyst\data_analysis\Lib\site-packages\holoviews\core\data\pandas.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return dataset.data.dtypes[idx].type
# C:\Users\shubh\Dropbox\My PC (LAPTOP-U0VR69II)\Desktop\Python Projects\Data Analyst\data_analysis\Lib\site-packages\holoviews\core\data\pandas.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return dataset.data.dtypes[idx].type
# <div id='6da17f11-a446-4937-8f82-df6a43786a1e'>
#   <div id="c6a47c19-b2e8-42cb-80aa-e3abde2ca926" data-root-id="6da17f11-a446-4937-8f82-df6a43786a1e" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"b8821d37-e17c-4b44-b8ce-6336ad9c5a26":{"version":"3.2.2","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"6da17f11-a446-4937-8f82-df6a43786a1e","attributes":{"name":"Row04703","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"d57daa8e-d195-4087-88dc-24db29b2108a","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"9c5d6621-1e9c-4847-b73d-71b232b1319f","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"24a82c38-5275-431a-b1b1-f0d0dcd19555","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"6f9d61fd-c0f9-4f12-87d2-77b16d4235b6","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"Figure","id":"c1a1f206-75c2-4062-9091-266bb7a13060","attributes":{"width":700,"height":300,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"Range1d","id":"5f621750-a328-4f8b-947c-886038ce4a0e","attributes":{"tags":[[["Year","Year",null]],[]],"start":1980.0,"end":2020.0,"reset_start":1980.0,"reset_end":2020.0}},"y_range":{"type":"object","name":"Range1d","id":"b7316ce7-9e68-4e9c-8cfd-bf318a214918","attributes":{"tags":[[["value","value",null]],{"type":"map","entries":[["invert_yaxis",false],["autorange",false]]}],"start":-67.89,"end":746.79,"reset_start":-67.89,"reset_end":746.79}},"x_scale":{"type":"object","name":"LinearScale","id":"6f445e7b-71e9-4ba5-a7f6-b7ad0122b9dd"},"y_scale":{"type":"object","name":"LinearScale","id":"86387802-844a-4e6d-8e1d-f3255d9adb0b"},"title":{"type":"object","name":"Title","id":"a2355dfa-7be0-4dcf-b484-7128ec845db9","attributes":{"text":"Sales performance over time","text_color":"black","text_font_size":"12pt"}},"renderers":[{"type":"object","name":"GlyphRenderer","id":"ecb5412b-a585-43b4-a71e-3ff52b5c95ba","attributes":{"name":"NA_Sales","data_source":{"type":"object","name":"ColumnDataSource","id":"5ef23a24-5a3b-4cc0-88fb-cbe825c7a7b7","attributes":{"selected":{"type":"object","name":"Selection","id":"89c6de94-6dc1-430b-8251-5c3fe87166f5","attributes":{"indices":[],"line_indices":[]}},"selection_policy":{"type":"object","name":"UnionRenderers","id":"d130a698-ef55-47ff-8630-b3b15203a983"},"data":{"type":"map","entries":[["Year",{"type":"ndarray","array":{"type":"bytes","data":"..."},"shape":[39],"dtype":"float64","order":"little"}],["value",{"type":"ndarray","array":{"type":"bytes","data":"..."},"shape":[39],"dtype":"float64","order":"little"}],["Variable",["NA_Sales","NA_Sales","NA_Sales","NA_Sales","NA_Sales","NA_Sales","NA_Sales","NA_Sales","NA_Sales","NA_Sales","NA_Sales","NA_Sales","NA_Sales","NA_Sales","NA_Sales","NA_Sales","NA_Sales","NA_Sales","NA_Sales","NA_Sales","NA_Sales","NA_Sales","NA_Sales","NA_Sales","NA_Sales","NA_Sales","NA_Sales","NA_Sales","NA_Sales","NA_Sales","NA_Sales","NA_Sales","NA_Sales","NA_Sales","NA_Sales","NA_Sales","NA_Sales","NA_Sales","NA_Sales"]]]}}},"view":{"type":"object","name":"CDSView","id":"2620f3af-aa2e-4407-b74f-bb910cc1d742","attributes":{"filter":{"type":"object","name":"AllIndices","id":"29b2e8f5-5699-4ab1-b1b8-a96ed0cf772e"}}},"glyph":{"type":"object","name":"Line","id":"20cd92e5-71a3-4d96-87dd-fc4eecd72d32","attributes":{"tags":["apply_ranges"],"x":{"type":"field","field":"Year"},"y":{"type":"field","field":"value"},"line_color":"#30a2da","line_width":2}},"selection_glyph":{"type":"object","name":"Line","id":"93638202-108b-4a73-94be-93207ce28718","attributes":{"tags":["apply_ranges"],"x":{"type":"field","field":"Year"},"y":{"type":"field","field":"value"} ...

# %%
co2_table = co2_pipeline.pipe(pn.widgets.Tabulator, pagination='remote', page_size = 10, sizing_mode='stretch_width') 
co2_table
# Out:
# <div id='736cfd2a-e862-4668-b096-6b4a440aa197'>
#   <div id="db827c36-e283-4f9b-a0df-6c52007e1be2" data-root-id="736cfd2a-e862-4668-b096-6b4a440aa197" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"5e1caac1-af29-485f-a807-10cbe8556952":{"version":"3.2.2","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"736cfd2a-e862-4668-b096-6b4a440aa197","attributes":{"name":"Row02772","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"baa4755d-ff2b-464c-a027-822750cecccc","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"2a1e037d-64d9-4f9c-b143-7840a5e27985","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"b816a7e1-3d2a-44e2-8d9b-7debd90fb0ff","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"5dff764d-02d4-4cc4-9f29-805febc2f8db","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/native.css"}}],"margin":0,"sizing_mode":"stretch_width","align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"6d06ab0f-a7a1-4c05-9a60-9d32daa68938","attributes":{"name":"Column02769","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"baa4755d-ff2b-464c-a027-822750cecccc"},{"id":"2a1e037d-64d9-4f9c-b143-7840a5e27985"},{"id":"b816a7e1-3d2a-44e2-8d9b-7debd90fb0ff"},{"id":"5dff764d-02d4-4cc4-9f29-805febc2f8db"}],"margin":0,"sizing_mode":"stretch_width","align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"bf95991b-129f-4475-8fc5-8ac005b42483","attributes":{"name":"Column02751","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"baa4755d-ff2b-464c-a027-822750cecccc"},{"id":"2a1e037d-64d9-4f9c-b143-7840a5e27985"},{"id":"b816a7e1-3d2a-44e2-8d9b-7debd90fb0ff"},{"id":"5dff764d-02d4-4cc4-9f29-805febc2f8db"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.widgets.CustomSelect","id":"4c412bb3-d1f4-4b35-b0fb-d9249803e039","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"baa4755d-ff2b-464c-a027-822750cecccc"},{"type":"object","name":"ImportedStyleSheet","id":"f2d16b52-a47c-4873-a584-7d0376ce27d8","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/select.css"}},{"id":"b816a7e1-3d2a-44e2-8d9b-7debd90fb0ff"},{"id":"5dff764d-02d4-4cc4-9f29-805febc2f8db"}],"width":300,"min_width":300,"margin":[5,10],"align":"start","title":"Publisher Names","options":["Activision","Atari","20th Century Fox Video Games","Coleco","Data Age","Imagic","Mattel Interactive","Men-A-Vision","Mystique","Parker Bros.","Starpath Corp.","Taito","Tigervision","Unknown","Answer Software","Avalon Interactive","Bomb","CBS Electronics","CPG Products","ITT Family Games","Quelle","Sega","Universal Gamex","Wizard Video Games","Nintendo","Hudson Soft","Namco Bandai Games","Capcom","Mycom","Konami Digital Entertainment","Enix Corporation","SquareSoft","Maxis","HAL Laboratory","Palcom","Angel Studios","BPS","Banpresto","Culture Brain","Epoch","Human Entertainment","Imagineer","Kemco","Square","Tecmo Koei","Arena Entertainment","ChunSoft","Electronic Arts","New World Computing","Ocean","Takara","Video System","Virgin Interactive","id Software","Acclaim Entertainment","Coconuts Japan","Hect","Imax","Interplay","Laguna","Misawa","SNK","Sammy Corporation","T&E Soft","TOHO","Titus","Victor Interactive","ASCII Entertainment","ArtDink","Asmik Corp","A ...

# %%
template = pn.template.FastListTemplate(
    title = "Video Games Sales Dashboard",
    sidebar = [
        pn.pane.Markdown("# Evolution of video games by genre and company",styles={'font-family':'Merriweather'}),
        pn.pane.GIF("giphy.gif",sizing_mode='scale_both'),
        pn.pane.Markdown("### Video games have been around for a long time, evolving from simple 2D games to complex 3D games. Video game companies are constantly innovating to create new and exciting games, and the industry has grown rapidly since the advent of the internet in 1995.Video games are available in many genres, and we have created a graph that shows how sales of different genres have trended over time.",styles={'font-family':'Oswald'})
    ],
    main = [pn.Row(pn.Column(publisher_select,sales_data_plot.panel(width=600),margin = (0,25)),co2_table.panel(width=600)),
           pn.Row(pn.Column(publisher_plot.panel(width =700),margin = (0,25)),pn.Column(publisher_genre_plot.panel(width=900)))],
    accent_base_color="#88d8b0",
    header_background="#88d8b0",
)

template.show()
# Out:
# Launching server at http://localhost:61570
# C:\Users\shubh\Dropbox\My PC (LAPTOP-U0VR69II)\Desktop\Python Projects\Data Analyst\data_analysis\Lib\site-packages\holoviews\core\data\pandas.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return dataset.data.dtypes[idx].type
# C:\Users\shubh\Dropbox\My PC (LAPTOP-U0VR69II)\Desktop\Python Projects\Data Analyst\data_analysis\Lib\site-packages\holoviews\core\data\pandas.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return dataset.data.dtypes[idx].type
# C:\Users\shubh\Dropbox\My PC (LAPTOP-U0VR69II)\Desktop\Python Projects\Data Analyst\data_analysis\Lib\site-packages\holoviews\core\data\pandas.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return dataset.data.dtypes[idx].type
# C:\Users\shubh\Dropbox\My PC (LAPTOP-U0VR69II)\Desktop\Python Projects\Data Analyst\data_analysis\Lib\site-packages\holoviews\core\data\pandas.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return dataset.data.dtypes[idx].type
# C:\Users\shubh\Dropbox\My PC (LAPTOP-U0VR69II)\Desktop\Python Projects\Data Analyst\data_analysis\Lib\site-packages\holoviews\core\util.py:1175: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   return pd.unique(values)
# C:\Users\shubh\Dropbox\My PC (LAPTOP-U0VR69II)\Desktop\Python Projects\Data Analyst\data_analysis\Lib\site-packages\holoviews\core\util.py:1175: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   return pd.unique(values)
# C:\Users\shubh\Dropbox\My PC (LAPTOP-U0VR69II)\Desktop\Python Projects\Data Analyst\data_analysis\Lib\site-packages\holoviews\core\data\pandas.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return dataset.data.dtypes[idx].type
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Row(id='b007c29b-5014-4c34-ba0a-b6c951092856', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='79242a0e-e796-40f8-a531-5197d992dd36', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='f85a199d-ce57-4b0a-94b8-4de37d1fd96a', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='82a7499e-5440-42f9-ab58-226d6fc71213', ...)
# C:\Users\shubh\Dropbox\My PC (LAPTOP-U0VR69II)\Desktop\Python Projects\Data Analyst\data_analysis\Lib\site-packages\holoviews\core\util.py:1175: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   return pd.unique(values)
# C:\Users\shubh\Dropbox\My PC (LAPTOP-U0VR69II)\Desktop\Python Projects\Data Analyst\data_analysis\Lib\site-packages\holoviews\core\util.py:1175: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   return pd.unique(values)
# C:\Users\shubh\Dropbox\My PC (LAPTOP-U0VR69II)\Desktop\Python Projects\Data Analyst\data_analysis\Lib\site-packages\holoviews\core\util.py:1175: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   return pd.unique(values)
# C:\Users\shubh\Dropbox\My PC (LAPTOP-U0VR69II)\Desktop\Python Projects\Data Analyst\data_analysis\Lib\site-packages\holoviews\core\util.py:1175: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   return pd.unique(values)
# C:\Users\shubh\Dropbox\My PC (LAPTOP-U0VR69II)\Desktop\Python Projects\Data Analyst\data_analysis\Lib\site-packages\holoviews\core\data\pandas.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return dataset.data.dtypes[idx].type
# C:\Users\shubh\Dropbox\My PC (LAPTOP-U0VR69II)\Desktop\Python Projects\Data Analyst\data_analysis\Lib\site-packages\holoviews\core\data\pandas.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return dataset.data.dtypes[idx].type
# C:\Users\shubh\Dropbox\My PC (LAPTOP-U0VR69II)\Desktop\Python Projects\Data Analyst\data_analysis\Lib\site-packages\holoviews\core\util.py:1175: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   return pd.unique(values)
# C:\Users\shubh\Dropbox\My PC (LAPTOP-U0VR69II)\Desktop\Python Projects\Data Analyst\data_analysis\Lib\site-packages\holoviews\core\util.py:1175: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   return pd.unique(values)
# C:\Users\shubh\Dropbox\My PC (LAPTOP-U0VR69II)\Desktop\Python Projects\Data Analyst\data_analysis\Lib\site-packages\holoviews\core\data\pandas.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return dataset.data.dtypes[idx].type
# C:\Users\shubh\Dropbox\My PC (LAPTOP-U0VR69II)\Desktop\Python Projects\Data Analyst\data_analysis\Lib\site-packages\holoviews\core\data\pandas.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return dataset.data.dtypes[idx].type
# C:\Users\shubh\Dropbox\My PC (LAPTOP-U0VR69II)\Desktop\Python Projects\Data Analyst\data_analysis\Lib\site-packages\holoviews\core\data\pandas.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return dataset.data.dtypes[idx].type
# C:\Users\shubh\Dropbox\My PC (LAPTOP-U0VR69II)\Desktop\Python Projects\Data Analyst\data_analysis\Lib\site-packages\holoviews\core\util.py:1175: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   return pd.unique(values)
# C:\Users\shubh\Dropbox\My PC (LAPTOP-U0VR69II)\Desktop\Python Projects\Data Analyst\data_analysis\Lib\site-packages\holoviews\core\util.py:1175: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   return pd.unique(values)
# C:\Users\shubh\Dropbox\My PC (LAPTOP-U0VR69II)\Desktop\Python Projects\Data Analyst\data_analysis\Lib\site-packages\holoviews\core\data\pandas.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return dataset.data.dtypes[idx].type
